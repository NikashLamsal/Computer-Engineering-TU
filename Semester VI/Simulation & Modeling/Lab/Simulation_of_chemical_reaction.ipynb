# %% [markdown]
# # Lab 1 : Simulation of Chemical Reaction

# %% [markdown]
# ## Objectives :
#
#  *  Todevelopthemathematicalmodelingofcontinuoussystem
#  *  To understand the behavior of a simple chemical reaction through computer simulation.
#  *  To study how the concentrations of reactants and products change over time during a reaction.
#  *  To plot and interpret concentration-versus-time graphs.
#  *   To gain practical knowledge of reaction kinetics and numerical simulation techniques.

# %% [markdown]
# ## Theory :

# %% [markdown]
# ## Introduction
#
# Chemical reactions are dynamic processes in which reactants are converted into products over time. In many chemical systems, both forward and reverse reactions occur simultaneously, leading to a condition known as dynamic equilibrium. At equilibrium, the rate of the forward reaction becomes equal to the rate of the reverse reaction, resulting in stable concentrations of the chemicals involved.
#
# In this lab, we simulate a reversible chemical reaction involving three chemicals:
#
# C1 + C2 ⇌ C3
#
# where:
# - C1 and C2 are reactants.
# - C3 is the product.
#
# The reaction is considered a **continuous system** because the concentrations of the chemicals change smoothly with time. Such systems are commonly modeled using **Ordinary Differential Equations (ODEs)**.
#
#
# The rate of reaction depends on several factors such as:
#
# 1. Initial amount of reactants
# 2. Temperature
# 3. Pressure
# 4. Humidity
# 5. Catalyst used
#
# ## Working Principle
#
# 1. Initialize the concentrations of C1, C2, and C3.
# 2. Define reaction constants K1 and K2.
# 3. Select a small time step Δt.
# 4. Compute the rate of change using the differential equations.
# 5. Update concentrations using Euler's method.
# 6. Repeat the process for the desired number of steps.
# 7. Store the results and visualize them using graphs.
# 8. Analyze how the concentrations approach equilibrium over time.
#
#
# ## Applications of Chemical Reaction Simulation
#
# Chemical reaction simulation has applications in various fields:
#
# ### 1. Engineering and Manufacturing
# - Process optimization
# - Chemical plant design
# - Production efficiency analysis
#
# ### 2. Healthcare and Medicine
# - Drug interaction studies
# - Pharmaceutical manufacturing
# - Biomedical research
#
# ### 3. Business and Economics
# - Demand and supply modeling
# - Market forecasting
# - Risk analysis
#
# ### 4. Transportation and Urban Planning
# - Traffic flow simulation
# - Smart city planning
# - Resource allocation
#
# ### 5. Defense and Military
# - Strategic simulations
# - Logistics planning
# - Operational analysis

# %% [markdown]
# ## Reaction 1

# %%
import numpy as np
import matplotlib.pyplot as plt
# Parameters
k1 = 0.03
k2 = 0.01
dt = 0.1
steps = 30
# Initial concentrations
c1 = [50.0] # Reactant A
c2 = [25.0] # Reactant B
c3 = [0.0] # Product C
# Open a file to write the results
with open("output.txt", "w") as file:
 # Write initial concentrations
 file.write(f"{c1[0]} {c2[0]} {c3[0]}\n")

 # Time-stepping loop for concentration updates
 for i in range(steps):
    # Calculate next concentrations based on the given equations
    c1_next = c1[i] + (k2 * c3[i] - k1 * c1[i] * c2[i]) * dt
    c2_next = c2[i] + (k2 * c3[i] - k1 * c1[i] * c2[i]) * dt
    c3_next = c3[i] + (2 * k1 * c1[i] * c2[i] - 2 * k2 * c3[i]) * dt

    # Append the new concentrations to the lists
    c1.append(c1_next)
    c2.append(c2_next)
    c3.append(c3_next)

 # Write concentrations to the file
 file.write(f"{c1_next} {c2_next} {c3_next}\n")
# Time points for plotting
time_points = np.arange(0, (steps + 1) * dt, dt)
# Plotting the results
plt.figure(figsize=(10, 6))
plt.plot(time_points, c1, label='Concentration of c1', color='blue')
plt.plot(time_points, c2, label='Concentration of c2', color='green')
plt.plot(time_points, c3, label='Concentration of c3', color='red')
plt.xlabel('Time (s)')
plt.ylabel('Concentration (mol)')
plt.title('Concentration vs Time')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Reaction 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# --- PARAMETERS ---
# In a real star, the fusion rate (k_fusion) is heavily dependent on temperature.
# We will use a scaled rate constant for a stable star core.
k_fusion = 0.0005  
dt = 0.5            # Time step (e.g., millions of years, or seconds in a reactor)
steps = 200

# Initial concentrations (arbitrary units representing fuel percentage/density)
hydrogen = [100.0]  # Start with 100% Hydrogen fuel
helium = [0.0]      # Zero Helium initially

# Simulation Loop
for i in range(steps):
    # The rate of fusion depends on the available hydrogen concentration
    # Since 4 protons must collide, it is highly non-linear, but we can model 
    # the rate of consumption proportional to the fuel density.
    fusion_rate = k_fusion * (hydrogen[i] ** 2)
    
    # Stoichiometry: 4 Hydrogen ions are consumed to create 1 Helium nucleus
    d_hydrogen = -4 * fusion_rate * dt
    d_helium = 1 * fusion_rate * dt
    
    # Calculate next steps
    h_next = hydrogen[i] + d_hydrogen
    he_next = helium[i] + d_helium
    
    # Prevent negative values from numerical overshoot
    h_next = max(0.0, h_next)
    
    hydrogen.append(h_next)
    helium.append(he_next)

# Time axis
time_points = np.arange(0, (steps + 1) * dt, dt)

# --- VISUALIZATION ---
plt.figure(figsize=(10, 6))
plt.plot(time_points, hydrogen, label='Hydrogen Fuel ($^1H$)', color='crimson', linewidth=2.5)
plt.plot(time_points, helium, label='Helium Ash ($^4He$)', color='gold', linewidth=2.5)

plt.xlabel('Time Scale (Stellar Core Age)', fontsize=12)
plt.ylabel('Relative Abundance (%)', fontsize=12)
plt.title('Simulation of Nuclear Fusion (Fuel Consumption vs. Ash Accumulation)', fontsize=13, fontweight='bold')
plt.legend(loc='center right')
plt.grid(True, alpha=0.3)

# %% [markdown]
# ## Reaction 3

# %%
import numpy as np
import matplotlib.pyplot as plt

# --- CLINICAL PARAMETERS ---
ka = 0.5    # Absorption rate (how fast the pill dissolves in the stomach)
k12 = 0.2   # Distribution rate (bloodstream -> body tissue)
k21 = 0.1   # Redistribution rate (body tissue -> bloodstream)
ke = 0.15   # Elimination rate (how fast the liver/kidneys clear the drug)

dt = 0.1    # Time steps in hours
steps = 240 # Simulate for 24 hours

# Initial states (assuming an oral dose of 100mg at t=0)
stomach = [100.0]      # Drug starting in the GI tract
bloodstream = [0.0]    # Central Compartment (Plasma concentration)
tissue = [0.0]         # Peripheral Compartment (Organs/Fat)

# Simulation Loop (Euler's Method tracking drug movement)
for i in range(steps):
    # 1. Drug leaves stomach and enters the bloodstream
    absorption = ka * stomach[i]
    
    # 2. Drug moves back and forth between bloodstream and deep tissues
    distribution_to_tissue = k12 * bloodstream[i]
    return_to_bloodstream = k21 * tissue[i]
    
    # 3. Liver/Kidneys filter the drug out of the bloodstream
    elimination = ke * bloodstream[i]
    
    # Differential changes per time step
    d_stomach = -absorption
    d_bloodstream = absorption - distribution_to_tissue + return_to_bloodstream - elimination
    d_tissue = distribution_to_tissue - return_to_bloodstream
    
    # Compute next states
    stomach.append(max(0.0, stomach[i] + d_stomach * dt))
    bloodstream.append(max(0.0, bloodstream[i] + d_bloodstream * dt))
    tissue.append(max(0.0, tissue[i] + d_tissue * dt))

# Time axis converted to hours
time_hours = np.arange(0, (steps + 1) * dt, dt)

# --- VISUALIZATION ---
plt.figure(figsize=(12, 7))
plt.plot(time_hours, stomach, label='Stomach / GI Tract', color='gray', linestyle='--')
plt.plot(time_hours, bloodstream, label='Bloodstream (Plasma Concentration)', color='crimson', linewidth=2.5)
plt.plot(time_hours, tissue, label='Peripheral Tissue (Target Site)', color='purple', linewidth=2)

# Define medical thresholds (Therapeutic Window)
plt.axhline(y=45, color='red', linestyle=':', label='Toxic Threshold (Overdose)')
plt.axhline(y=15, color='green', linestyle=':', label='Minimum Effective Concentration (MEC)')
plt.fill_between(time_hours, 15, 45, color='green', alpha=0.05, label='Safe Therapeutic Range')

# Graph styling
plt.xlabel('Time Elapsed (Hours)', fontsize=12)
plt.ylabel('Drug Mass / Concentration (mg)', fontsize=12)
plt.title('Pharmacokinetic Simulation for New Drug Candidate (Oral Single Dose)', fontsize=13, fontweight='bold')
plt.xlim(0, 24)
plt.ylim(0, 110)
plt.legend(loc='upper right', shadow=True)
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ## Discussion
#
# The first simulated a chemical reaction in which two substances reacted together, resulting in the formation of a product. In this process, both reactions  reaction forward and reverse reaction – take place concurrently and reach equilibrium when their rates become equal. The simulation revealed that there was gradual decay in the amount of reactants and simultaneous growth in the amount of product formed as time passed.
#
# In the second simulation, nuclear fusion was depicted, as in which hydrogen nuclei combine into helium nuclei. The result of such a process shows a gradual decay in hydrogen fuel and a rise in the amount of helium. With decreasing hydrogen quantity, the rate of fusion reduces.
#
# The third simulation described the drug dynamics in patients. According to the results of the simulation, the concentration in the stomach decreased, whereas the amount of substance in the bloodstream grew quickly and slowly declined after that. The tissue compartment revealed that there is a delay in both the increase and decay of concentration, which is caused by drug exchange between body compartments. The therapeutic range presented on the diagram depicts the time period when the drug concentration is effective and safe for treatment.
#
#
# ## Conclusion
#
# This lab successfully simulated a reversible chemical reaction using Python. The reaction kinetics were modeled through ordinary differential equations and solved numerically using Euler's method. The concentration-versus-time graph provided a clear visualization of the reaction process and demonstrated the concept of dynamic equilibrium. The experiment enhanced understanding of continuous systems, numerical simulation techniques, and scientific modeling.
